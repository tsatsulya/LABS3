# %%
def I(Kx, R0):
    return Kx/R0

def H(I, N0, R):
    return I*N0/2/np.pi/R

def B(R, C, U, S, N):
    return R*C*U/S/N

# %%
import matplotlib.pyplot as plt

import numpy as np

#железо - 11
x1 = np.array([5, 4.8, 4, 4, 3.6, 3.2, 2.8, 2, 1.8, 1.2, 1.1]) 
#феррит
x2 = np.array([7, 6, 5, 4.4, 3.2, 3, 2.8, 2.4, 1.9, 1.9])
#пармаллой
x3 = np.array([3.2, 2, 1.8, 1.6, 1.4, 1.4, 1.4, 1.4, 1.4, 1.2, 1.2, 1, 0.8])


y1 = np.array([6.6, 6.2, 5.6, 5.5, 5, 4.9, 4.8, 3.4, 3.2, 2.1, 1.7])
y2 = np.array([6, 5.2,  5, 4.5, 3, 2.4, 2, 1.6, 0.8, 0.8])
y3 = np.array([3.6, 3.5, 3.2, 2.8, 2.6, 2.4, 2, 1.6, 1.2, 0.8,0.5, 0.4, 0.1])


n0 = 1.256*10**(-6)


print(max(y1/x1/n0)) #железо
print(max(y2/x2/n0)) #феррит
print(max(y3/x3/n0)) #пармаллой
#plt.plot(x1, y1)
#plt.plot(x2, y2)
#plt.plot(x3, y3)
# Out:
# 1415428.167020524
# 814273.306311523
# 1478616.9244767975

# %%
epsilon = 1e-3
plt.figure(figsize=(10, 7))
mask = np.abs(y1) < epsilon
plt.scatter(x1, y1, color='orange', s=40, marker='o')

# %%
epsilon = 1e-3
plt.figure(figsize=(10, 7))
mask = np.abs(y2) < epsilon
plt.scatter(x2, y2, color='red', s=40, marker='o')

# %%
epsilon = 1e-3
plt.figure(figsize=(10, 7))
mask = np.abs(y3) < epsilon
plt.scatter(x3, y3, color='blue', s=40, marker='o')
